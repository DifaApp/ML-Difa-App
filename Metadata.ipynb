# %%
# !gdown --id 1Hs_p9uEEBOh3GpZGzMnOFBfSLsz8Bq1x
# !gdown --id 1hRIqLqXoBhXfLk9yn5riZ1p-RUecQjMV
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Hs_p9uEEBOh3GpZGzMnOFBfSLsz8Bq1x
# To: /content/Difa_model2_coba_dulu_maseh.tflite
# 100% 14.2M/14.2M [00:00<00:00, 43.4MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1hRIqLqXoBhXfLk9yn5riZ1p-RUecQjMV
# To: /content/LABELS.txt
# 100% 11.5k/11.5k [00:00<00:00, 25.8MB/s]

# %%
from tflite_support import metadata as _metadata


_MODEL_PATH = "/content/Difa_model2_coba_dulu_maseh.tflite"
_LABEL_FILE = "/content/LABELS.txt"


displayer = _metadata.MetadataDisplayer.with_model_file(_MODEL_PATH)
json_file = displayer.get_metadata_json()

print(json_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-4a2f6a62ebcb> in <cell line: 1>()
# ----> 1 from tflite_support import metadata as _metadata
#       2
#       3
#       4 _MODEL_PATH = "/content/Difa_model2_coba_dulu_maseh.tflite"
#       5 _LABEL_FILE = "/content/LABELS.txt"
#
# ModuleNotFoundError: No module named 'tflite_support'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
